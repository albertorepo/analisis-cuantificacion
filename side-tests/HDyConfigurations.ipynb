# %% [markdown]
# # HDy with different configurations

# %% [markdown]
# ## Preparation

# %%
import numpy as np
random_state = 42
np.random.seed(random_state)
import os, glob
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.5f' % x)

from tqdm import tqdm
from sklearn.model_selection import train_test_split
from quantification.metrics import binary_kl_divergence, absolute_error
from quantification.dm import HDy, EDy

import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
from sklearn.exceptions import DataConversionWarning
from pandas.core.common import SettingWithCopyWarning

warnings.simplefilter("ignore", DataConversionWarning)
warnings.simplefilter("ignore", SettingWithCopyWarning)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.exceptions import NotFittedError
from sklearn.utils.extmath import softmax

class LinearRegressionWrapper(LogisticRegression):
    """Class which overrides the sigmoid function of sklearn's LogisticRegression"""

    def __init__(self, alpha=1., penalty='l2', dual=False, tol=1e-4, C=1.0,
                 fit_intercept=True, intercept_scaling=1, class_weight=None,
                 random_state=None, solver='liblinear', max_iter=100,
                 multi_class='ovr', verbose=0, warm_start=False, n_jobs=1):
        super(LinearRegressionWrapper, self).__init__(penalty, dual, tol, C, fit_intercept, intercept_scaling, class_weight, random_state, solver,
                         max_iter, multi_class, verbose, warm_start, n_jobs)
        self.alpha = alpha

    def _predict_proba(self, X):
        prob = self.decision_function(X)
        prob = -1 * prob * self.alpha
        np.exp(prob, prob)
        prob += 1
        np.reciprocal(prob, prob)
        if prob.ndim == 1:
            return np.vstack([1 - prob, prob]).T
        else:
            # OvR normalization, like LibLinear's predict_probability
            prob /= prob.sum(axis=1).reshape((prob.shape[0], -1))
            return prob

    def predict_proba(self, X):
        if not hasattr(self, "coef_"):
            raise NotFittedError("Call fit before prediction")
        calculate_ovr = self.coef_.shape[0] == 1 or self.multi_class == "ovr"
        if calculate_ovr:
            return self._predict_proba(X)
        else:
            return softmax(self.decision_function(X), copy=False)

# %%
datasets_dir = "datasets"
dataset_files = [file for file in glob.glob(os.path.join(datasets_dir, "*.csv")) if "k9" not in file]
dataset_names = [os.path.split(name)[-1][:-4] for name in dataset_files]
print("There are a total of {} datasets.".format(len(dataset_names)))
# Out:
# There are a total of 43 datasets.

# %%
n_datasets = len(dataset_names)

columns=['dataset', 'alpha', 'bins', 'truth', 'predictions', 'kld', 'mae']
errors_df = pd.DataFrame(columns=columns)

# %% [markdown]
# ## Utils

# %% [markdown]
# #### Standard scale data

# %%
from sklearn.preprocessing import StandardScaler

def normalize(X_train, X_test):
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    return X_train, X_test

# %% [markdown]
# #### Load data

# %%
def load_data(dfile):
    df = pd.read_csv(dfile, header=None)
    X = df.iloc[:, :-1].values
    y = df.iloc[:, -1].values.astype(np.int)
    if -1 in np.unique(y):
        y[y == -1] = 0
        
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=random_state)
    
    X_train, X_test = normalize(X_train, X_test)
    
    return X_train, X_test, y_train, y_test

# %% [markdown]
# #### GridSearch parameters

# %%
estimator_grid = {'C': [10 ** i for i in range(-3, 3)]}
grid_params = dict(verbose=False)

# %% [markdown]
# ## Experiments

# %%
for alpha in [0.2, 0.4, 0.6, 0.8, 1]:
    for b in [8, 16, 32, 64, 132]:
        hdy = HDy(b=b, estimator_class=LinearRegressionWrapper(alpha=alpha, random_state=random_state), estimator_grid=estimator_grid, grid_params=grid_params)

        for dname, dfile in zip(dataset_names, dataset_files)

            X_train, X_test, y_train, y_test = load_data(dfile)

            hdy.fit(X_train, y_train)
            prev_pred = hdy.predict(X_test)[1]

            prev_true = np.unique(y_test, return_counts=True)[1][1] / len(X_test)
            kld = binary_kl_divergence(prev_true, prev_pred)
            mae = absolute_error(prev_true, prev_pred)

            errors_df = errors_df.append(pd.DataFrame([[dname, alpha, b, prev_true, prev_pred, kld, mae]], columns=columns))
# Out:
#  79%|███████▉  | 34/43 [00:46<00:12,  1.36s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:04<00:00,  1.49s/it]
#  79%|███████▉  | 34/43 [00:47<00:12,  1.39s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:06<00:00,  1.54s/it]
#  79%|███████▉  | 34/43 [00:45<00:11,  1.33s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:03<00:00,  1.49s/it]
#  81%|████████▏ | 35/43 [00:49<00:11,  1.42s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:08<00:00,  1.59s/it]
#  81%|████████▏ | 35/43 [00:43<00:10,  1.25s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:02<00:00,  1.46s/it]
#  79%|███████▉  | 34/43 [00:34<00:09,  1.02s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [00:53<00:00,  1.24s/it]
#  81%|████████▏ | 35/43 [00:43<00:10,  1.25s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:01<00:00,  1.43s/it]
#  81%|████████▏ | 35/43 [00:39<00:09,  1.13s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [00:55<00:00,  1.30s/it]
#  81%|████████▏ | 35/43 [00:45<00:10,  1.30s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:01<00:00,  1.43s/it]
#  81%|████████▏ | 35/43 [00:46<00:10,  1.32s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:03<00:00,  1.48s/it]
#  79%|███████▉  | 34/43 [00:36<00:09,  1.07s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [00:52<00:00,  1.22s/it]
#  79%|███████▉  | 34/43 [00:39<00:10,  1.16s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [00:56<00:00,  1.31s/it]
#  79%|███████▉  | 34/43 [00:47<00:12,  1.41s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:04<00:00,  1.49s/it]
#  81%|████████▏ | 35/43 [00:48<00:10,  1.37s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:06<00:00,  1.54s/it]
#  81%|████████▏ | 35/43 [00:45<00:10,  1.29s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:02<00:00,  1.45s/it]
#  81%|████████▏ | 35/43 [00:46<00:10,  1.34s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:03<00:00,  1.49s/it]
#  79%|███████▉  | 34/43 [00:46<00:12,  1.37s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:01<00:00,  1.44s/it]
#  81%|████████▏ | 35/43 [00:48<00:10,  1.37s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:06<00:00,  1.54s/it]
#  79%|███████▉  | 34/43 [00:41<00:10,  1.22s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [00:58<00:00,  1.37s/it]
#  79%|███████▉  | 34/43 [00:40<00:10,  1.20s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [00:59<00:00,  1.37s/it]
#  79%|███████▉  | 34/43 [00:44<00:11,  1.30s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:01<00:00,  1.43s/it]
#  79%|███████▉  | 34/43 [00:40<00:10,  1.20s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [00:59<00:00,  1.38s/it]
#  81%|████████▏ | 35/43 [00:39<00:09,  1.14s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [00:56<00:00,  1.31s/it]
#  79%|███████▉  | 34/43 [00:44<00:11,  1.31s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [01:01<00:00,  1.42s/it]
#  79%|███████▉  | 34/43 [00:40<00:10,  1.20s/it]/home/castano/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 100%|██████████| 43/43 [00:57<00:00,  1.34s/it]

# %%
for alpha in tqdm([0.2, 0.4, 0.6, 0.8, 1]):
        edy = EDy(estimator_class=LinearRegressionWrapper(alpha=alpha, random_state=random_state), estimator_grid=estimator_grid, grid_params=grid_params)

        for dname, dfile in zip(dataset_names, dataset_files):

            X_train, X_test, y_train, y_test = load_data(dfile)

            edy.fit(X_train, y_train)
            prev_pred = edy.predict(X_test)[1]

            prev_true = np.unique(y_test, return_counts=True)[1][1] / len(X_test)
            kld = binary_kl_divergence(prev_true, prev_pred)
            mae = absolute_error(prev_true, prev_pred)

            errors_df = errors_df.append(pd.DataFrame([[dname, alpha, b, prev_true, prev_pred, kld, mae]], columns=columns))
# Out:
# 100%|██████████| 5/5 [26:05<00:00, 313.02s/it]

# %%
errors_df.groupby(['alpha', 'bins'])[['kld', 'mae']].agg(['mean', 'median'])
# Out:
#                  kld             mae
#                 mean  median    mean  median
# alpha   bins
# 0.20000 8    0.01004 0.00190 0.03331 0.02118
#         16   0.01004 0.00190 0.03331 0.02118
#         32   0.01004 0.00190 0.03331 0.02118
#         64   0.01004 0.00190 0.03331 0.02118
#         132  0.01004 0.00190 0.03331 0.02118
# 0.40000 8    0.00968 0.00180 0.03248 0.01935
#         16   0.00968 0.00180 0.03248 0.01935
#         32   0.00968 0.00180 0.03248 0.01935
#         64   0.00968 0.00180 0.03248 0.01935
#         132  0.00968 0.00180 0.03248 0.01935
# 0.60000 8    0.00941 0.00146 0.03164 0.01930
#         16   0.00941 0.00146 0.03164 0.01930
#         32   0.00941 0.00146 0.03164 0.01930
#         64   0.00941 0.00146 0.03164 0.01930
#         132  0.00941 0.00146 0.03164 0.01930
# 0.80000 8    0.00919 0.00130 0.03087 0.01928
#         16   0.00919 0.00130 0.03087 0.01928
#         32   0.00919 0.00130 0.03087 0.01928
#         64   0.00919 0.00130 0.03087 0.01928
#         132  0.00919 0.00130 0.03087 0.01928
# 1.00000 8    0.00900 0.00129 0.03030 0.01687
#         16   0.00900 0.00129 0.03030 0.01687
#         32   0.00900 0.00129 0.03030 0.01687
#         64   0.00900 0.00129 0.03030 0.01687
#         132  0.00900 0.00129 0.03030 0.01687

# %%
errors_df.groupby(['alpha'])[['kld', 'mae']].agg(['mean', 'median'])
# Out:
#             kld             mae
#            mean  median    mean  median
# alpha
# 0.20000 0.01004 0.00190 0.03331 0.02118
# 0.40000 0.00968 0.00180 0.03248 0.01935
# 0.60000 0.00941 0.00146 0.03164 0.01930
# 0.80000 0.00919 0.00130 0.03087 0.01928
# 1.00000 0.00900 0.00129 0.03030 0.01687
